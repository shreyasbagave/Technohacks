# %%
# Import required Libraries
import numpy as np
import pandas as pd

# %%
# Statistical operations on Training data
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# datatypes of each column
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Removing columns with other datatypes except (int , float)
new_df = df.drop(['Name','Sex','Ticket','Cabin','Embarked'],axis=1)
new_df
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
# Calculate 'mean' value of each column
new_df.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
# Calculate 'median' value of each column
new_df.median()
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
# Calculate 'mode' value of each column
new_df.mode()
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# 0              1       0.0     3.0  24.0    0.0    0.0  8.05
# 1              2       NaN     NaN   NaN    NaN    NaN   NaN
# 2              3       NaN     NaN   NaN    NaN    NaN   NaN
# 3              4       NaN     NaN   NaN    NaN    NaN   NaN
# 4              5       NaN     NaN   NaN    NaN    NaN   NaN
# ..           ...       ...     ...   ...    ...    ...   ...
# 886          887       NaN     NaN   NaN    NaN    NaN   NaN
# 887          888       NaN     NaN   NaN    NaN    NaN   NaN
# 888          889       NaN     NaN   NaN    NaN    NaN   NaN
# 889          890       NaN     NaN   NaN    NaN    NaN   NaN
# 890          891       NaN     NaN   NaN    NaN    NaN   NaN
#
# [891 rows x 7 columns]

# %%
# Calculate 'standard deviation' value of each column
new_df.std()
# Out:
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %%
# Calculate 'minimum' value of each column
new_df.min()
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
# Calculate 'maximum' value of each column
new_df.max()
# Out:
# PassengerId    891.0000
# Survived         1.0000
# Pclass           3.0000
# Age             80.0000
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %%
# Calculate 'skew' value of each column
# "Skewness" = Skewness is a statistical measure of asymmetric distribution of data.
new_df.skew()
# Out:
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.389108
# SibSp          3.695352
# Parch          2.749117
# Fare           4.787317
# dtype: float64

# %%
# Calculate 'count' of each column with non-null values
new_df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Age            714
# SibSp          891
# Parch          891
# Fare           891
# dtype: int64

# %%
# Statistical summary of each column in dataset
new_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
